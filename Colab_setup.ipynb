# %% [markdown]
# <a href="https://colab.research.google.com/github/jdencontro/ECEC247-C147_Final_Project/blob/dev%2Fjiustine_colab/Colab_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Step 1: Mount the Google Drive
#
# Remember to use GPU runtime before mounting your Google Drive. (Runtime --> Change runtime type).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Step 2: Open the project directory
#
# Replace `Your_Dir` with your own path.

# %%
cd '/content/drive/MyDrive/emg2qwerty'
# Out:
# /content/drive/MyDrive/emg2qwerty

# %% [markdown]
# ### Step 3: Install required packages
#
# After installing them, Colab will require you to restart the session.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Step 4: Start your experiments!
#
# - Remember to download and copy the dataset to this directory: `Your_Dir/emg2qwerty/data`.
# - You may now start your experiments with any scripts! Below are examples of single-user training and testing (greedy decoding).
# - **There are two ways to track the logs:**
#   - 1. Keep `--multirun`, and the logs will not be printed here, but they will be saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/submitit_logs/`.
#   - 2. Comment out `--multirun` and the logs will be printed in this notebook, but they will not be saved.

# %% [markdown]
# #### Training
#
# - The checkpoints are saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/checkpoints/`.

# %%
# Single-user training
# !python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1 \
  --multirun
# Out:
# [2026-03-05 18:55:26,285][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-05/18-55-26
# [2026-03-05 18:55:26,288][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1
# object address  : 0x7f68528229e0
# object refcount : 3
# object type     : 0xa2a4e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.12/dist-packages/submitit/local/_local.py", line 16, in <module>
#     controller.run()
#   File "/usr/local/lib/python3.12/dist-packages/submitit/local/local.py", line 375, in run
#     exit_codes = self.wait()
#                  ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/submitit/local/local.py", line 366, in wait
#     time.sleep(1.0 / freq)
# KeyboardInterrupt

# %% [markdown]
# #### Testing:
#
# - Replace `Your_Path_to_Checkpoint` with your checkpoint path.

# %%
import os
os.environ['HYDRA_FULL_ERROR'] = '0'

# %%
# Single-user testing
import os
os.environ['HYDRA_FULL_ERROR'] = '1'
# !python -m emg2qwerty.train \
  user="single_user"\
  "checkpoint='/content/drive/MyDrive/emg2qwerty/logs/2026-03-05/14-24-50/checkpoints/epoch=54-step=6600.ckpt'"\
  train=False\
  trainer.accelerator=gpu\
  decoder=ctc_greedy\
  hydra.launcher.mem_gb=64\
  --multirun
# Out:
# [2026-03-05 19:43:06,416][HYDRA] Submitit 'local' sweep output dir : logs/2026-03-05/19-43-06
# [2026-03-05 19:43:06,418][HYDRA] 	#0 : user=single_user checkpoint='/content/drive/MyDrive/emg2qwerty/logs/2026-03-05/14-24-50/checkpoints/epoch=54-step=6600.ckpt' train=False trainer.accelerator=gpu decoder=ctc_greedy
